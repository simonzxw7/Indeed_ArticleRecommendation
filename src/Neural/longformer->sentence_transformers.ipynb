# %% [markdown]
# Longformer
# --
# The Longformer with an attention mechanism that scales linearly with sequence length, making it easy to process documents of thousands of tokens or longer. Longformer's attention mechanism is a drop-in replacement for the standard self-attention and combines a local windowed attention with a task motivated global attention.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Pre-processing the content
# --

# %%
import json
import pandas as pd

# %%
f = open("/content/drive/MyDrive/Gensim_LDA/source_data/article.json", encoding="utf-8")
articles = []

for line in f:
    articles.append(json.loads(line))
art_train = pd.DataFrame(pd.DataFrame(articles))

# %%
f = open("/content/drive/MyDrive/Gensim_LDA/source_data/careerpathpage.json", encoding="utf-8")
cp = []

for line in f:
    cp.append(json.loads(line))
cp_train = pd.DataFrame(pd.DataFrame(cp))

# %%
f = open("/content/drive/MyDrive/Gensim_LDA/source_data/coverletter.json", encoding="utf-8")
cl = []

for line in f:
    cl.append(json.loads(line))
cl_train = pd.DataFrame(pd.DataFrame(cl))

# %%
f = open("/content/drive/MyDrive/Gensim_LDA/source_data/resumesamplepage.json", encoding="utf-8")
res = []

for line in f:
    res.append(json.loads(line))
res_train = pd.DataFrame(pd.DataFrame(res))

# %%
def remove_hyperlinks(corpus, col):
    """
    Remove hypoerlinks from the content
    """  
    for i, content in enumerate(corpus[col]):
        content = content.split("\n")
        for j, cont in enumerate(content): 
            if cont!='':
                if "https" in cont or "http" in cont:
                    content[j] = ""
        corpus.iloc[i]["content"] = " ".join(content)
    return corpus

# %%
art_train = remove_hyperlinks(art_train, "content")
cl_train = remove_hyperlinks(cl_train, "contentA")
res_train  = remove_hyperlinks(res_train, "contentA")

# %% [markdown]
# Loading Longformer Model
# --

# %%
# !conda create --name longformer python=3.7
# !conda activate longformer
# !conda install cudatoolkit=10.0
# !pip install git+https://github.com/allenai/longformer.git
# Out:
# /bin/bash: conda: command not found
# /bin/bash: conda: command not found
# /bin/bash: conda: command not found
# Collecting git+https://github.com/allenai/longformer.git
#   Cloning https://github.com/allenai/longformer.git to /tmp/pip-req-build-_xy74mfy
#   Running command git clone -q https://github.com/allenai/longformer.git /tmp/pip-req-build-_xy74mfy
# Collecting transformers@ git+http://github.com/ibeltagy/transformers.git@longformer_encoder_decoder#egg=transformers
#   Cloning http://github.com/ibeltagy/transformers.git (to revision longformer_encoder_decoder) to /tmp/pip-install-ty8zl5ef/transformers
#   Running command git clone -q http://github.com/ibeltagy/transformers.git /tmp/pip-install-ty8zl5ef/transformers
#   Running command git checkout -b longformer_encoder_decoder --track origin/longformer_encoder_decoder
#   Switched to a new branch 'longformer_encoder_decoder'
#   Branch 'longformer_encoder_decoder' set up to track remote branch 'longformer_encoder_decoder' from 'origin'.
# Collecting pytorch-lightning@ git+http://github.com/ibeltagy/pytorch-lightning.git@v0.8.5_fixes#egg=pytorch-lightning
#   Cloning http://github.com/ibeltagy/pytorch-lightning.git (to revision v0.8.5_fixes) to /tmp/pip-install-ty8zl5ef/pytorch-lightning
#   Running command git clone -q http://github.com/ibeltagy/pytorch-lightning.git /tmp/pip-install-ty8zl5ef/pytorch-lightning
#   Running command git checkout -b v0.8.5_fixes --track origin/v0.8.5_fixes
#   Switched to a new branch 'v0.8.5_fixes'
#   Branch 'v0.8.5_fixes' set up to track remote branch 'v0.8.5_fixes' from 'origin'.
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from longformer==0.1) (1.8.1+cu101)
# Collecting tensorboardX
#   Downloading https://files.pythonhosted.org/packages/07/84/46421bd3e0e89a92682b1a38b40efc22dafb6d8e3d947e4ceefd4a5fabc7/tensorboardX-2.2-py2.py3-none-any.whl (120kB)
#      |████████████████████████████████| 122kB 8.6MB/s
# Collecting test-tube==0.7.5
#   Downloading https://files.pythonhosted.org/packages/91/f0/5c32f2fbd824f32354f7f4632c957163071597bb2c6a4105f507bc9af7c0/test_tube-0.7.5.tar.gz
# Collecting nlp
#   Downloading https://files.pythonhosted.org/packages/09/e3/bcdc59f3434b224040c1047769c47b82705feca2b89ebbc28311e3764782/nlp-0.4.0-py3-none-any.whl (1.7MB)
#      |████████████████████████████████| 1.7MB 14.1MB/s
# Collecting rouge_score
#   Downloading https://files.pythonhosted.org/packages/1f/56/a81022436c08b9405a5247b71635394d44fe7e1dbedc4b28c740e09c2840/rouge_score-0.0.4-py2.py3-none-any.whl
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from transformers@ git+http://github.com/ibeltagy/transformers.git@longformer_encoder_decoder#egg=transformers->longformer==0.1) (1.19.5)
# Collecting tokenizers==0.8.1.rc2
#   Downloading https://files.pythonhosted.org/packages/75/26/c02ba92ecb8b780bdae4a862d351433c2912fe49469dac7f87a5c85ccca6/tokenizers-0.8.1rc2-cp37-cp37m-manylinux1_x86_64.whl (3.0MB)
#      |████████████████████████████████| 3.0MB 36.1MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers@ git+http://github.com/ibeltagy/transformers.git@longformer_encoder_decoder#egg=transformers->longformer==0.1) (20.9)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers@ git+http://github.com/ibeltagy/transformers.git@longformer_encoder_decoder#egg=transformers->longformer==0.1) (3.0.12)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers@ git+http://github.com/ibeltagy/transformers.git@longformer_encoder_decoder#egg=transformers->longformer==0.1) (2.23.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers@ git+http://github.com/ibeltagy/transformers.git@longformer_encoder_decoder#egg=transformers->longformer==0.1) (4.41.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers@ git+http://github.com/ibeltagy/transformers.git@longformer_encoder_decoder#egg=transformers->longformer==0.1) (2019.12.20)
# Collecting sentencepiece!=0.1.92
#   Downloading https://files.pythonhosted.org/packages/f5/99/e0808cb947ba10f575839c43e8fafc9cc44e4a7a2c8f79c60db48220a577/sentencepiece-0.1.95-cp37-cp37m-manylinux2014_x86_64.whl (1.2MB)
#      |████████████████████████████████| 1.2MB 47.2MB/s
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/75/ee/67241dc87f266093c533a2d4d3d69438e57d7a90abb216fa076e7d475d4a/sacremoses-0.0.45-py3-none-any.whl (895kB)
#      |████████████████████████████████| 901kB 52.9MB/s
# Collecting future>=0.17.1
#   Downloading https://files.pythonhosted.org/packages/45/0b/38b06fd9b92dc2b68d58b75f900e97884c45bedd2ff83203d933cf5851c9/future-0.18.2.tar.gz (829kB)
#      |████████████████████████████████| 829kB 58.2MB/s
# Collecting PyYAML>=5.1
#   Downloading https://files.pythonhosted.org/packages/7a/a5/393c087efdc78091afa2af9f1378762f9821c9c1d7a22c5753fb5ac5f97a/PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636kB)
#      |████████████████████████████████| 645kB 48.0MB/s
# Requirement already satisfied: tensorboard>=1.14 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning@ git+http://github.com/ibeltagy/pytorch-lightning.git@v0.8.5_fixes#egg=pytorch-lightning->longformer==0.1) (2.5.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.6.0->longformer==0.1) (3.7.4.3)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.7/dist-packages (from tensorboardX->longformer==0.1) (3.12.4)
# Requirement already satisfied: pandas>=0.20.3 in /usr/local/lib/python3.7/dist-packages (from test-tube==0.7.5->longformer==0.1) (1.1.5)
# Requirement already satisfied: imageio>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from test-tube==0.7.5->longformer==0.1) (2.4.1)
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from nlp->longformer==0.1) (0.3.3)
# Requirement already satisfied: pyarrow>=0.16.0 in /usr/local/lib/python3.7/dist-packages (from nlp->longformer==0.1) (3.0.0)
# Collecting xxhash
#   Downloading https://files.pythonhosted.org/packages/7d/4f/0a862cad26aa2ed7a7cd87178cbbfa824fc1383e472d63596a0d018374e7/xxhash-2.0.2-cp37-cp37m-manylinux2010_x86_64.whl (243kB)
#      |████████████████████████████████| 245kB 45.7MB/s
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from rouge_score->longformer==0.1) (3.2.5)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.7/dist-packages (from rouge_score->longformer==0.1) (0.12.0)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.7/dist-packages (from rouge_score->longformer==0.1) (1.15.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers@ git+http://github.com/ibeltagy/transformers.git@longformer_encoder_decoder#egg=transformers->longformer==0.1) (2.4.7)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers@ git+http://github.com/ibeltagy/transformers.git@longformer_encoder_decoder#egg=transformers->longformer==0.1) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers@ git+http://github.com/ibeltagy/transformers.git@longformer_encoder_decoder#egg=transformers->longformer==0.1) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers@ git+http://github.com/ibeltagy/transformers.git@longformer_encoder_decoder#egg=transformers->longformer==0.1) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers@ git+http://github.com/ibeltagy/transformers.git@longformer_encoder_decoder#egg=transformers->longformer==0.1) (2020.12.5)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers@ git+http://github.com/ibeltagy/transformers.git@longformer_encoder_decoder#egg=transformers->longformer==0.1) (1.0.1)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers@ git+http://github.com/ibeltagy/transformers.git@longformer_encoder_decoder#egg=transformers->longformer==0.1) (7.1.2)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=1.14->pytorch-lightning@ git+http://github.com/ibeltagy/pytorch-lightning.git@v0.8.5_fixes#egg=pytorch-lightning->longformer==0.1) (1.30.0)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.7/dist-packages (from tensorboard>=1.14->pytorch-lightning@ git+http://github.com/ibeltagy/pytorch-lightning.git@v0.8.5_fixes#egg=pytorch-lightning->longformer==0.1) (0.36.2)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=1.14->pytorch-lightning@ git+http://github.com/ibeltagy/pytorch-lightning.git@v0.8.5_fixes#egg=pytorch-lightning->longformer==0.1) (1.34.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=1.14->pytorch-lightning@ git+http://github.com/ibeltagy/pytorch-lightning.git@v0.8.5_fixes#egg=pytorch-lightning->longformer==0.1) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=1.14->pytorch-lightning@ git+http://github.com/ibeltagy/pytorch-lightning.git@v0.8.5_fixes#egg=pytorch-lightning->longformer==0.1) (0.4.4)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=1.14->pytorch-lightning@ git+http://github.com/ibeltagy/pytorch-lightning.git@v0.8.5_fixes#egg=pytorch-lightning->longformer==0.1) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=1.14->pytorch-lightning@ git+http://github.com/ibeltagy/pytorch-lightning.git@v0.8.5_fixes#egg=pytorch-lightning->longformer==0.1) (3.3.4)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=1.14->pytorch-lightning@ git+http://github.com/ibeltagy/pytorch-lightning.git@v0.8.5_fixes#egg=pytorch-lightning->longformer==0.1) (56.1.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=1.14->pytorch-lightning@ git+http://github.com/ibeltagy/pytorch-lightning.git@v0.8.5_fixes#egg=pytorch-lightning->longformer==0.1) (1.8.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.20.3->test-tube==0.7.5->longformer==0.1) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.20.3->test-tube==0.7.5->longformer==0.1) (2018.9)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from imageio>=2.3.0->test-tube==0.7.5->longformer==0.1) (7.1.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard>=1.14->pytorch-lightning@ git+http://github.com/ibeltagy/pytorch-lightning.git@v0.8.5_fixes#egg=pytorch-lightning->longformer==0.1) (4.2.2)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard>=1.14->pytorch-lightning@ git+http://github.com/ibeltagy/pytorch-lightning.git@v0.8.5_fixes#egg=pytorch-lightning->longformer==0.1) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard>=1.14->pytorch-lightning@ git+http://github.com/ibeltagy/pytorch-lightning.git@v0.8.5_fixes#egg=pytorch-lightning->longformer==0.1) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=1.14->pytorch-lightning@ git+http://github.com/ibeltagy/pytorch-lightning.git@v0.8.5_fixes#egg=pytorch-lightning->longformer==0.1) (1.3.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard>=1.14->pytorch-lightning@ git+http://github.com/ibeltagy/pytorch-lightning.git@v0.8.5_fixes#egg=pytorch-lightning->longformer==0.1) (4.0.1)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.7/dist-packages (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth<2,>=1.6.3->tensorboard>=1.14->pytorch-lightning@ git+http://github.com/ibeltagy/pytorch-lightning.git@v0.8.5_fixes#egg=pytorch-lightning->longformer==0.1) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=1.14->pytorch-lightning@ git+http://github.com/ibeltagy/pytorch-lightning.git@v0.8.5_fixes#egg=pytorch-lightning->longformer==0.1) (3.1.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard>=1.14->pytorch-lightning@ git+http://github.com/ibeltagy/pytorch-lightning.git@v0.8.5_fixes#egg=pytorch-lightning->longformer==0.1) (3.4.1)
# Building wheels for collected packages: pytorch-lightning
#   Building wheel for pytorch-lightning (PEP 517) ... done
#   Created wheel for pytorch-lightning: filename=pytorch_lightning-0.8.5-cp37-none-any.whl size=313138 sha256=815ea363c778e35d49e030870b46603499284290e573817f389b715e691207aa
#   Stored in directory: /tmp/pip-ephem-wheel-cache-1aq2om99/wheels/52/3e/bb/0ca91e975dc17933cd9b698e5ba340c4bf283e8405936da0d1
# Successfully built pytorch-lightning
# Building wheels for collected packages: longformer, transformers, test-tube, future
#   Building wheel for longformer (setup.py) ... done
#   Created wheel for longformer: filename=longformer-0.1-cp37-none-any.whl size=548880 sha256=7ed887ed38372ecd54db4054b4e22f1f182c2745cd09e859ebcfd04eeb34c279
#   Stored in directory: /tmp/pip-ephem-wheel-cache-1aq2om99/wheels/be/82/60/69b954e03d633f9db8c184922d93643719f549ac5a23dc8bf1
#   Building wheel for transformers (setup.py) ... done
#   Created wheel for transformers: filename=transformers-3.1.0-cp37-none-any.whl size=884317 sha256=d89251bb7b4004fb52d8a261cddbaa3995408dd6be3795556ed43d1a1b24d1d4
#   Stored in directory: /tmp/pip-ephem-wheel-cache-1aq2om99/wheels/9e/97/5a/80ebd634ccf0e475fe303a434f2584f127d456c2194f7e1b9d
#   Building wheel for test-tube (setup.py) ... done
#   Created wheel for test-tube: filename=test_tube-0.7.5-cp37-none-any.whl size=25357 sha256=1dab775a5ce79ffba23589e3439db0b9125a35ca86494d1dc81f61f7909499b9
#   Stored in directory: /root/.cache/pip/wheels/02/52/96/c8b6f3c345cfd3284845ef50818c6996a5658006fe50e40e98
#   Building wheel for future (setup.py) ... done
#   Created wheel for future: filename=future-0.18.2-cp37-none-any.whl size=491058 sha256=4b5641a55f42140a6e7a32ed42547c922c4c5c29aea54543b58b5480874fcced
#   Stored in directory: /root/.cache/pip/wheels/8b/99/a0/81daf51dcd359a9377b110a8a886b3895921802d2fc1b2397e
# Successfully built longformer transformers test-tube future
# Installing collected packages: tokenizers, sentencepiece, sacremoses, transformers, future, PyYAML, pytorch-lightning, tensorboardX, test-tube, xxhash, nlp, rouge-score, longformer
#   Found existing installation: future 0.16.0
#     Uninstalling future-0.16.0:
#       Successfully uninstalled future-0.16.0
#   Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed PyYAML-5.4.1 future-0.18.2 longformer-0.1 nlp-0.4.0 pytorch-lightning-0.8.5 rouge-score-0.0.4 sacremoses-0.0.45 sentencepiece-0.1.95 tensorboardX-2.2 test-tube-0.7.5 tokenizers-0.8.1rc2 transformers-3.1.0 xxhash-2.0.2

# %%
# !pip install sentence_transformers
# Out:
# Collecting sentence_transformers
#   Downloading https://files.pythonhosted.org/packages/cc/75/df441011cd1726822b70fbff50042adb4860e9327b99b346154ead704c44/sentence-transformers-1.2.0.tar.gz (81kB)
#      |████████████████████████████████| 81kB 5.6MB/s
# Requirement already satisfied: transformers<5.0.0,>=3.1.0 in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (3.1.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (4.41.1)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (1.8.1+cu101)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (0.9.1+cu101)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (1.19.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (0.22.2.post1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (1.4.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (3.2.5)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (0.1.95)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=3.1.0->sentence_transformers) (20.9)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=3.1.0->sentence_transformers) (0.0.45)
# Requirement already satisfied: tokenizers==0.8.1.rc2 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=3.1.0->sentence_transformers) (0.8.1rc2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=3.1.0->sentence_transformers) (2.23.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=3.1.0->sentence_transformers) (2019.12.20)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=3.1.0->sentence_transformers) (3.0.12)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.6.0->sentence_transformers) (3.7.4.3)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.7/dist-packages (from torchvision->sentence_transformers) (7.1.2)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sentence_transformers) (1.0.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk->sentence_transformers) (1.15.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers<5.0.0,>=3.1.0->sentence_transformers) (2.4.7)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers<5.0.0,>=3.1.0->sentence_transformers) (7.1.2)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=3.1.0->sentence_transformers) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=3.1.0->sentence_transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=3.1.0->sentence_transformers) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=3.1.0->sentence_transformers) (1.24.3)
# Building wheels for collected packages: sentence-transformers
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-1.2.0-cp37-none-any.whl size=123339 sha256=9baeb39486f5210ae107b5a523b3452561fc37a678282d5d7082268ecb78c263
#   Stored in directory: /root/.cache/pip/wheels/0f/06/f7/faaa96fdda87462b4fd5c47b343340e9d5531ef70d0eef8242
# Successfully built sentence-transformers
# Installing collected packages: sentence-transformers
# Successfully installed sentence-transformers-1.2.0

# %%
import torch
from transformers import LongformerModel, LongformerTokenizer

# %%
device = "cuda" if torch.cuda.is_available else "cpu"

# %%
model = LongformerModel.from_pretrained('allenai/longformer-base-4096').to(device)
tokenizer = LongformerTokenizer.from_pretrained('allenai/longformer-base-4096')
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=694.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=597257159.0, style=ProgressStyle(descri…
# Some weights of LongformerModel were not initialized from the model checkpoint at allenai/longformer-base-4096 and are newly initialized: ['longformer.embeddings.position_ids']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=898823.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=456318.0, style=ProgressStyle(descripti…

# %% [markdown]
# Checking for top 10 content Title's
# --
#
# Note: Just selected 10 as the cuda runs out of memory beyond that.

# %%
title1 =list(art_train['contentTitle'][:10])

# %%
input_ids = tokenizer(title1, padding=True, return_tensors="pt")

# %%
outputs = model(**input_ids.to(device))

# %%
outputs[0].shape
# Out:
# torch.Size([10, 18, 768])

# %%
from sentence_transformers import SentenceTransformer, util
cosine_scores = util.pytorch_cos_sim(outputs[1], outputs[1])
cosine_scores.shape
# Out:
# torch.Size([10, 10])

# %%
pairs = []
for i in range(len(cosine_scores)-1):
    for j in range(i+1, len(cosine_scores)):
        pairs.append({'index': [i, j], 'score': cosine_scores[i][j]})

# %%
import pandas as pd
from collections import defaultdict

pairs = sorted(pairs, key=lambda x: x['score'], reverse=True)
dict_ = defaultdict(list)
for pair in pairs:
    i, j = pair['index']
    dict_["sent1"].append(title1[i]) 
    dict_["sent2"].append(title1[j])
    dict_["scores"].append(pair["score"].item())

# %%
df = pd.DataFrame.from_dict(dict_).sort_values(by=['scores'], ascending=False)

# %% [markdown]
# Longformer results by Cosine similarity
# --

# %%
df.head(60)
# Out:
#                                                 sent1  ...    scores
# 0       Collaboration Skills: Definition and Examples  ...  0.999523
# 1          Management Skills: Definition and Examples  ...  0.999465
# 2       Collaboration Skills: Definition and Examples  ...  0.999347
# 3          Management Skills: Definition and Examples  ...  0.998996
# 4       Collaboration Skills: Definition and Examples  ...  0.998816
# 5       Collaboration Skills: Definition and Examples  ...  0.998804
# 6             Communication Skills for Career Success  ...  0.998664
# 7                 High School Resume Tips and Example  ...  0.998651
# 8   Becoming a Manager: How To Develop a Work Sche...  ...  0.998578
# 9             Communication Skills for Career Success  ...  0.998574
# 10  Becoming a Manager: How To Develop a Work Sche...  ...  0.998487
# 11         Management Skills: Definition and Examples  ...  0.998370
# 12  Becoming a Manager: How To Develop a Work Sche...  ...  0.998295
# 13      Collaboration Skills: Definition and Examples  ...  0.998256
# 14  Becoming a Manager: How To Develop a Work Sche...  ...  0.998223
# 15            Communication Skills for Career Success  ...  0.998198
# 16            How to Create a Resume Template in Word  ...  0.998189
# 17         Management Skills: Definition and Examples  ...  0.998178
# 18            How to Create a Resume Template in Word  ...  0.998170
# 19  Becoming a Manager: How To Develop a Work Sche...  ...  0.998111
# 20  Becoming a Manager: How To Develop a Work Sche...  ...  0.998103
# 21   Problem-Solving Skills: Definitions and Examples  ...  0.998056
# 22            How to Create a Resume Template in Word  ...  0.998056
# 23                High School Resume Tips and Example  ...  0.998035
# 24            Communication Skills for Career Success  ...  0.998027
# 25            How to Create a Resume Template in Word  ...  0.998023
# 26                High School Resume Tips and Example  ...  0.998019
# 27  Becoming a Manager: How To Develop a Work Sche...  ...  0.998014
# 28            How to Create a Resume Template in Word  ...  0.997952
# 29   Problem-Solving Skills: Definitions and Examples  ...  0.997916
# 30      Collaboration Skills: Definition and Examples  ...  0.997875
# 31                  17 of the Best Self-Employed Jobs  ...  0.997764
# 32  Becoming a Manager: How To Develop a Work Sche...  ...  0.997713
# 33  What Happens To My Resume After I Click Apply?...  ...  0.997711
# 34            Communication Skills for Career Success  ...  0.997696
# 35  Becoming a Manager: How To Develop a Work Sche...  ...  0.997657
# 36            How to Create a Resume Template in Word  ...  0.997617
# 37                High School Resume Tips and Example  ...  0.997565
# 38            How to Create a Resume Template in Word  ...  0.997511
# 39         Management Skills: Definition and Examples  ...  0.997441
# 40   Problem-Solving Skills: Definitions and Examples  ...  0.997436
# 41            How to Create a Resume Template in Word  ...  0.997381
# 42                  17 of the Best Self-Employed Jobs  ...  0.997359
# 43      Collaboration Skills: Definition and Examples  ...  0.997218
# 44            Communication Skills for Career Success  ...  0.997024
#
# [45 rows x 3 columns]

# %% [markdown]
# Sentence Transformer to rescue!
# --
#
# Sentence Transformer reads the semantic contexuality behind the text and then checks the similarity between the texts.

# %%
title1 =list(art_train['contentTitle'])[:200]

# %%
from sentence_transformers import SentenceTransformer, util
model = SentenceTransformer('paraphrase-MiniLM-L12-v2')
embeddings1 = model.encode(title1, convert_to_tensor=True) 
cosine_scores = util.pytorch_cos_sim(embeddings1, embeddings1)

pairs = []
for i in range(len(cosine_scores)-1):
    for j in range(i+1, len(cosine_scores)):
        pairs.append({'index': [i, j], 'score': cosine_scores[i][j]})

import pandas as pd
from collections import defaultdict

pairs = sorted(pairs, key=lambda x: x['score'], reverse=True)
dict_ = defaultdict(list)

for pair in pairs:
    i, j = pair['index']

    dict_["sent1"].append(title1[i]) 
    dict_["sent2"].append(title1[j])
    dict_["scores"].append(pair["score"].item())    

df = pd.DataFrame.from_dict(dict_).sort_values(by=['scores'], ascending=False)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=122959036.0), HTML(value='')))

# %%
pd.set_option('max_colwidth', 400)
df[df["sent1"]=="Combination Resume Tips and Examples"][:5]
# Out:
#                                     sent1  ...    scores
# 2    Combination Resume Tips and Examples  ...  0.881121
# 4    Combination Resume Tips and Examples  ...  0.850433
# 31   Combination Resume Tips and Examples  ...  0.799398
# 189  Combination Resume Tips and Examples  ...  0.677714
# 242  Combination Resume Tips and Examples  ...  0.653828
#
# [5 rows x 3 columns]

# %%
df[df["sent1"]=="High School Resume Tips and Example"][:5]
# Out:
#                                    sent1  ...    scores
# 6    High School Resume Tips and Example  ...  0.846611
# 17   High School Resume Tips and Example  ...  0.823630
# 28   High School Resume Tips and Example  ...  0.804529
# 49   High School Resume Tips and Example  ...  0.769507
# 100  High School Resume Tips and Example  ...  0.719584
#
# [5 rows x 3 columns]

# %% [markdown]
# Sentence transformer model results ordered by cosine similarity scores in descending order
# --

# %%
df.head(20)
# Out:
#                                                                   sent1  ...    scores
# 0                  How To Write a Cover Letter (Plus Tips and Examples)  ...  0.892443
# 1                 How to Format a Cover Letter (With Tips and Examples)  ...  0.882038
# 2                                  Combination Resume Tips and Examples  ...  0.881121
# 3                                Chronological Resume Tips and Examples  ...  0.856826
# 4                                  Combination Resume Tips and Examples  ...  0.850433
# 5                                   Best Careers for ISTJ Personalities  ...  0.846749
# 6                                   High School Resume Tips and Example  ...  0.846611
# 7             39 Strengths and Weaknesses to Discuss in a Job Interview  ...  0.842401
# 8                                   Best Careers for ISTP Personalities  ...  0.840465
# 9                      Here's Everything You Should Include on a Resume  ...  0.840029
# 10  How to Write a Letter of Recommendation (With Template and Example)  ...  0.837949
# 11                                     9 College Resume Tips + Examples  ...  0.834739
# 12                             Resume Objectives: 70+ Examples and Tips  ...  0.833065
# 13                        Letter of Recommendation for College Students  ...  0.830980
# 14                How to Format a Cover Letter (With Tips and Examples)  ...  0.829733
# 15                               Chronological Resume Tips and Examples  ...  0.826258
# 16                               Chronological Resume Tips and Examples  ...  0.825000
# 17                                  High School Resume Tips and Example  ...  0.823630
# 18                                 How to Make a Resume (With Examples)  ...  0.819582
# 19                               Chronological Resume Tips and Examples  ...  0.818265
#
# [20 rows x 3 columns]

# %% [markdown]
# Trying the sntence transformer on article content
# --

# %%
cont =list(art_train['content'])[:200]

# %%
from sentence_transformers import SentenceTransformer, util
model = SentenceTransformer('paraphrase-MiniLM-L12-v2')
embeddings1 = model.encode(cont, convert_to_tensor=True) 
cosine_scores = util.pytorch_cos_sim(embeddings1, embeddings1)

pairs = []
for i in range(len(cosine_scores)-1):
    for j in range(i+1, len(cosine_scores)):
        pairs.append({'index': [i, j], 'score': cosine_scores[i][j]})

import pandas as pd
from collections import defaultdict

pairs = sorted(pairs, key=lambda x: x['score'], reverse=True)
dict_ = defaultdict(list)

for pair in pairs:
    i, j = pair['index']

    dict_["sent1"].append(title1[i]) 
    dict_["sent2"].append(title1[j])
    dict_["scores"].append(pair["score"].item())    

df = pd.DataFrame.from_dict(dict_).sort_values(by=['scores'], ascending=False)

# %%
df.head(20)
# Out:
#                                                                       sent1  ...    scores
# 0       How to Write a Letter of Recommendation (With Template and Example)  ...  0.827835
# 1                                       Best Careers for ENFP Personalities  ...  0.814514
# 2                                   How to Make a Resume for Your First Job  ...  0.813814
# 3                                         How To List Education on a Resume  ...  0.795837
# 4                                      How to Make a Resume (With Examples)  ...  0.793513
# 5                                         How To List Education on a Resume  ...  0.789733
# 6                                            The Essential Job Search Guide  ...  0.789454
# 7   Career Advice for Service Members: Making a Transition To Civilian Life  ...  0.766813
# 8                                   How to Create a Resume Template in Word  ...  0.766515
# 9              Resignation Letter Due to a Career Change: Tips and Examples  ...  0.765828
# 10                         Here's Everything You Should Include on a Resume  ...  0.764699
# 11                                  Communication Skills for Career Success  ...  0.761054
# 12                                           The Essential Job Search Guide  ...  0.760792
# 13            How to Explain Your Reasons for Leaving a Job (With Examples)  ...  0.759651
# 14                               Management Skills: Definition and Examples  ...  0.749849
# 15                        6 Universal Rules for Resume Writing (With Video)  ...  0.748881
# 16                               Management Skills: Definition and Examples  ...  0.747406
# 17                              Technical Resume Writing: Tips and Examples  ...  0.746476
# 18                                  How to Create a Resume Template in Word  ...  0.745396
# 19                                     How to Make a Resume (With Examples)  ...  0.742078
#
# [20 rows x 3 columns]

# %% [markdown]
# Checking other sentence transformer paraphrase sentence textual similarity models for better cosine similarity scores.
# --

# %%
from sentence_transformers import SentenceTransformer, util
model = SentenceTransformer('paraphrase-MiniLM-L6-v2')
embeddings1 = model.encode(title1, convert_to_tensor=True) 
cosine_scores = util.pytorch_cos_sim(embeddings1, embeddings1)

pairs = []
for i in range(len(cosine_scores)-1):
    for j in range(i+1, len(cosine_scores)):
        pairs.append({'index': [i, j], 'score': cosine_scores[i][j]})

import pandas as pd
from collections import defaultdict

pairs = sorted(pairs, key=lambda x: x['score'], reverse=True)
dict_ = defaultdict(list)

for pair in pairs:
    i, j = pair['index']
    dict_["sent1"].append(title1[i]) 
    dict_["sent2"].append(title1[j])
    dict_["scores"].append(pair["score"].item())    

df = pd.DataFrame.from_dict(dict_).sort_values(by=['scores'], ascending=False)
df.head(20)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=83426730.0), HTML(value='')))
#                                                                   sent1  ...    scores
# 0                                   Best Careers for ISTJ Personalities  ...  0.908848
# 1                                   Best Careers for ENFP Personalities  ...  0.889055
# 2                                   Best Careers for ESFJ Personalities  ...  0.884238
# 3                                Chronological Resume Tips and Examples  ...  0.882135
# 4                 How to Format a Cover Letter (With Tips and Examples)  ...  0.874603
# 5                                   High School Resume Tips and Example  ...  0.865415
# 6                                   Best Careers for ISTP Personalities  ...  0.851982
# 7                                Chronological Resume Tips and Examples  ...  0.849624
# 8                           Technical Resume Writing: Tips and Examples  ...  0.842368
# 9                                  Combination Resume Tips and Examples  ...  0.840752
# 10                                 How to Make a Resume (With Examples)  ...  0.837428
# 11                     Functional Resume: Definition, Tips and Examples  ...  0.833698
# 12                                     9 College Resume Tips + Examples  ...  0.828187
# 13                                 Combination Resume Tips and Examples  ...  0.826852
# 14                          Technical Resume Writing: Tips and Examples  ...  0.823875
# 15                                                How To Change Careers  ...  0.823329
# 16                               Chronological Resume Tips and Examples  ...  0.816557
# 17                                 Combination Resume Tips and Examples  ...  0.815029
# 18  How to Write a Letter of Recommendation (With Template and Example)  ...  0.814353
# 19                 How To Write a Cover Letter (Plus Tips and Examples)  ...  0.810998
#
# [20 rows x 3 columns]

# %%
from sentence_transformers import SentenceTransformer, util
model = SentenceTransformer('paraphrase-MiniLM-L6-v2')
embeddings1 = model.encode(cont, convert_to_tensor=True) 
cosine_scores = util.pytorch_cos_sim(embeddings1, embeddings1)

pairs = []
for i in range(len(cosine_scores)-1):
    for j in range(i+1, len(cosine_scores)):
        pairs.append({'index': [i, j], 'score': cosine_scores[i][j]})

import pandas as pd
from collections import defaultdict

pairs = sorted(pairs, key=lambda x: x['score'], reverse=True)
dict_ = defaultdict(list)

for pair in pairs:
    i, j = pair['index']
    dict_["sent1"].append(title1[i]) 
    dict_["sent2"].append(title1[j])
    dict_["scores"].append(pair["score"].item())    

df = pd.DataFrame.from_dict(dict_).sort_values(by=['scores'], ascending=False)
df.head(20)
# Out:
#                                                                       sent1  ...    scores
# 0                                            The Essential Job Search Guide  ...  0.888103
# 1                               Technical Resume Writing: Tips and Examples  ...  0.864793
# 2                              Human Resources: Definition and How It Works  ...  0.843934
# 3                                   How to Make a Resume for Your First Job  ...  0.841326
# 4                                         How To List Education on a Resume  ...  0.833636
# 5                  How To List Volunteer Work on Your Resume (With Example)  ...  0.823916
# 6                                         How To List Education on a Resume  ...  0.822620
# 7                                       Best Careers for ENFP Personalities  ...  0.819723
# 8                                             Guide To Updating Your Resume  ...  0.815710
# 9                                   How to Create a Resume Template in Word  ...  0.812128
# 10                              Technical Resume Writing: Tips and Examples  ...  0.810234
# 11                                            Guide To Updating Your Resume  ...  0.809103
# 12      How to Write a Letter of Recommendation (With Template and Example)  ...  0.808021
# 13                                      Best Careers for ESFJ Personalities  ...  0.796861
# 14                                     How to Make a Resume (With Examples)  ...  0.795363
# 15                              Technical Resume Writing: Tips and Examples  ...  0.793791
# 16  Career Advice for Service Members: Making a Transition To Civilian Life  ...  0.793655
# 17                              Technical Resume Writing: Tips and Examples  ...  0.790564
# 18                                  How to Create a Resume Template in Word  ...  0.788762
# 19                    How to Format a Cover Letter (With Tips and Examples)  ...  0.788354
#
# [20 rows x 3 columns]

# %%
from sentence_transformers import SentenceTransformer, util
model = SentenceTransformer('msmarco-MiniLM-L-12-v3')
embeddings1 = model.encode(title1, convert_to_tensor=True) 
cosine_scores = util.pytorch_cos_sim(embeddings1, embeddings1)

pairs = []
for i in range(len(cosine_scores)-1):
    for j in range(i+1, len(cosine_scores)):
        pairs.append({'index': [i, j], 'score': cosine_scores[i][j]})

import pandas as pd
from collections import defaultdict

pairs = sorted(pairs, key=lambda x: x['score'], reverse=True)
dict_ = defaultdict(list)

for pair in pairs:
    i, j = pair['index']

    dict_["sent1"].append(title1[i]) 
    dict_["sent2"].append(title1[j])
    dict_["scores"].append(pair["score"].item())    

df = pd.DataFrame.from_dict(dict_).sort_values(by=['scores'], ascending=False)
df.head(20)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=122509599.0), HTML(value='')))
#                                                                   sent1  ...    scores
# 0                                   Best Careers for ISTJ Personalities  ...  0.883420
# 1   How to Write a Letter of Recommendation (With Template and Example)  ...  0.855017
# 2                 How to Format a Cover Letter (With Tips and Examples)  ...  0.850855
# 3                                   Best Careers for ESFJ Personalities  ...  0.828206
# 4                  How To Write a Cover Letter (Plus Tips and Examples)  ...  0.793890
# 5                                   Best Careers for ENFP Personalities  ...  0.793882
# 6                                           14 Sales Jobs That Pay Well  ...  0.793466
# 7                             How to Introduce Yourself in an Interview  ...  0.777560
# 8                   15 Phone Interview Questions (With Example Answers)  ...  0.771728
# 9                                           14 Sales Jobs That Pay Well  ...  0.770760
# 10                        25 Career Options for Former Military Members  ...  0.767014
# 11                             12 Tough Interview Questions and Answers  ...  0.766434
# 12             5 Situational Interview Questions (With Example Answers)  ...  0.765220
# 13                                         18 Top Economics Degree Jobs  ...  0.763170
# 14                                  Best Careers for ISTP Personalities  ...  0.761619
# 15                                      20 Part-Time Jobs That Pay Well  ...  0.761480
# 16                                                 9 Popular Trade Jobs  ...  0.760530
# 17                  15 Phone Interview Questions (With Example Answers)  ...  0.759681
# 18                                                   Jobs That Pay Well  ...  0.758499
# 19                                  Best Careers for ISTJ Personalities  ...  0.754625
#
# [20 rows x 3 columns]

# %%
from sentence_transformers import SentenceTransformer, util
model = SentenceTransformer('msmarco-MiniLM-L-12-v3')
embeddings1 = model.encode(cont, convert_to_tensor=True) 
cosine_scores = util.pytorch_cos_sim(embeddings1, embeddings1)

pairs = []
for i in range(len(cosine_scores)-1):
    for j in range(i+1, len(cosine_scores)):
        pairs.append({'index': [i, j], 'score': cosine_scores[i][j]})

import pandas as pd
from collections import defaultdict

pairs = sorted(pairs, key=lambda x: x['score'], reverse=True)
dict_ = defaultdict(list)

for pair in pairs:
    i, j = pair['index']

    dict_["sent1"].append(title1[i]) 
    dict_["sent2"].append(title1[j])
    dict_["scores"].append(pair["score"].item())    

df = pd.DataFrame.from_dict(dict_).sort_values(by=['scores'], ascending=False)
df.head(20)
# Out:
#                                                                   sent1  ...    scores
# 0          Resignation Letter Due to a Career Change: Tips and Examples  ...  0.911585
# 1                         10 Resume Writing Tips To Help You Land a Job  ...  0.908975
# 2                                Chronological Resume Tips and Examples  ...  0.893147
# 3                     6 Universal Rules for Resume Writing (With Video)  ...  0.891810
# 4                                        The Essential Job Search Guide  ...  0.888012
# 5              What Does "Business Casual" Mean? (With Example Outfits)  ...  0.880033
# 6                            Management Skills: Definition and Examples  ...  0.873066
# 7      How to Write a Letter of Intent (With Examples and Writing Tips)  ...  0.872647
# 8   How to Write a Letter of Recommendation (With Template and Example)  ...  0.870218
# 9                                 Soft Skills: Definitions and Examples  ...  0.869144
# 10                    6 Universal Rules for Resume Writing (With Video)  ...  0.866311
# 11                    6 Universal Rules for Resume Writing (With Video)  ...  0.865422
# 12                             Guide To Business Attire (With Examples)  ...  0.851870
# 13                                Guide: How To Get a Job After College  ...  0.844186
# 14                    6 Universal Rules for Resume Writing (With Video)  ...  0.840273
# 15                How to Format a Cover Letter (With Tips and Examples)  ...  0.838861
# 16                21 Job Interview Tips: How To Make a Great Impression  ...  0.835603
# 17                                  Best Careers for ISTJ Personalities  ...  0.831931
# 18    How to Answer "Tell Me About Yourself" (Tips and Example Answers)  ...  0.830892
# 19                          How to Write a Resume Employers Will Notice  ...  0.829052
#
# [20 rows x 3 columns]

# %% [markdown]
# "msmarco-MiniLM-L-6-v3" seems to be more semantically aligned and produces better results for both titles and content
# --

# %%
from sentence_transformers import SentenceTransformer, util
model = SentenceTransformer('msmarco-MiniLM-L-6-v3')
embeddings1 = model.encode(title1, convert_to_tensor=True) 
cosine_scores = util.pytorch_cos_sim(embeddings1, embeddings1)

pairs = []
for i in range(len(cosine_scores)-1):
    for j in range(i+1, len(cosine_scores)):
        pairs.append({'index': [i, j], 'score': cosine_scores[i][j]})

import pandas as pd
from collections import defaultdict

pairs = sorted(pairs, key=lambda x: x['score'], reverse=True)
dict_ = defaultdict(list)

for pair in pairs:
    i, j = pair['index']

    dict_["sent1"].append(title1[i]) 
    dict_["sent2"].append(title1[j])
    dict_["scores"].append(pair["score"].item())    

df = pd.DataFrame.from_dict(dict_).sort_values(by=['scores'], ascending=False)
df.head(60)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=82977541.0), HTML(value='')))
#                                                                   sent1  ...    scores
# 0                                   Best Careers for ISTJ Personalities  ...  0.909458
# 1                                   Best Careers for ENFP Personalities  ...  0.891321
# 2                                   Best Careers for ESFJ Personalities  ...  0.847839
# 3                         Letter of Recommendation for College Students  ...  0.845687
# 4                 How to Format a Cover Letter (With Tips and Examples)  ...  0.822301
# 5                  How To Write a Cover Letter (Plus Tips and Examples)  ...  0.817732
# 6                                   High School Resume Tips and Example  ...  0.814334
# 7             39 Strengths and Weaknesses to Discuss in a Job Interview  ...  0.804420
# 8   How to Write a Letter of Recommendation (With Template and Example)  ...  0.803100
# 9                                                    Jobs That Pay Well  ...  0.794318
# 10                                                   Jobs That Pay Well  ...  0.793396
# 11                                  Best Careers for ISTP Personalities  ...  0.792475
# 12                                 How to Make a Resume (With Examples)  ...  0.789636
# 13                           Management Skills: Definition and Examples  ...  0.786052
# 14                                  Best Careers for ISTJ Personalities  ...  0.784107
# 15                                  Best Careers for ENFP Personalities  ...  0.783811
# 16                           Management Skills: Definition and Examples  ...  0.768787
# 17                                  Best Careers for ISTJ Personalities  ...  0.764347
# 18                  15 Phone Interview Questions (With Example Answers)  ...  0.760064
# 19                             Resume Objectives: 70+ Examples and Tips  ...  0.755695
# 20                             12 Tough Interview Questions and Answers  ...  0.753225
# 21                            Computer Skills: Definitions and Examples  ...  0.750828
# 22                                  Best Careers for ISTJ Personalities  ...  0.748751
# 23                            How to Introduce Yourself in an Interview  ...  0.745517
# 24                                  Best Careers for ESFJ Personalities  ...  0.744735
# 25                                  Best Careers for ENFP Personalities  ...  0.744408
# 26             8 Common Exit Interview Questions (With Example Answers)  ...  0.744087
# 27                  15 Phone Interview Questions (With Example Answers)  ...  0.743448
# 28                                  Best Careers for INTP Personalities  ...  0.741139
# 29             8 Common Exit Interview Questions (With Example Answers)  ...  0.734937
# 30                        Collaboration Skills: Definition and Examples  ...  0.730072
# 31                                  Best Careers for INFP Personalities  ...  0.729438
# 32                                 How to Make a Resume (With Examples)  ...  0.729410
# 33                       Interpersonal Skills: Definitions and Examples  ...  0.727365
# 34                                     9 College Resume Tips + Examples  ...  0.718994
# 35                                 Combination Resume Tips and Examples  ...  0.717129
# 36                  15 Phone Interview Questions (With Example Answers)  ...  0.712848
# 37                          Technical Resume Writing: Tips and Examples  ...  0.711545
# 38                                  Best Careers for ENTJ Personalities  ...  0.711540
# 39                              How to Create a Resume Template in Word  ...  0.711420
# 40                        Collaboration Skills: Definition and Examples  ...  0.711128
# 41                                          14 Sales Jobs That Pay Well  ...  0.709931
# 42                                  Best Careers for ENFP Personalities  ...  0.708667
# 43                                  Best Careers for INTP Personalities  ...  0.707783
# 44                                  Best Careers for ISTP Personalities  ...  0.706155
# 45                               Chronological Resume Tips and Examples  ...  0.705725
# 46                                         18 Top Economics Degree Jobs  ...  0.705607
# 47                                                   Jobs That Pay Well  ...  0.704799
# 48      Email Examples: How to Respond to an Employer Interview Request  ...  0.703021
# 49                                  Best Careers for ESFJ Personalities  ...  0.702989
# 50                                    Work-From-Home Jobs That Pay Well  ...  0.701076
# 51                                 Combination Resume Tips and Examples  ...  0.700019
# 52                                  Best Careers for ISTP Personalities  ...  0.698912
# 53                           Technical Skills: Definitions and Examples  ...  0.698901
# 54                                                 9 Popular Trade Jobs  ...  0.695455
# 55                        Collaboration Skills: Definition and Examples  ...  0.695323
# 56             8 Common Exit Interview Questions (With Example Answers)  ...  0.695163
# 57                                                   Jobs That Pay Well  ...  0.694960
# 58                               Chronological Resume Tips and Examples  ...  0.693989
# 59                  15 Phone Interview Questions (With Example Answers)  ...  0.691953
#
# [60 rows x 3 columns]

# %%
########## final #############

cont =list(art_train['content'])[:200]
from sentence_transformers import SentenceTransformer, util
model = SentenceTransformer('msmarco-MiniLM-L-6-v3')
embeddings1 = model.encode(cont, convert_to_tensor=True) 
cosine_scores = util.pytorch_cos_sim(embeddings1, embeddings1)

pairs = []
for i in range(len(cosine_scores)-1):
    for j in range(i+1, len(cosine_scores)):
        pairs.append({'index': [i, j], 'score': cosine_scores[i][j]})

import pandas as pd
from collections import defaultdict

pairs = sorted(pairs, key=lambda x: x['score'], reverse=True)
dict_ = defaultdict(list)

for pair in pairs:
    i, j = pair['index']

    dict_["sent1"].append(title1[i]) 
    dict_["sent2"].append(title1[j])
    dict_["scores"].append(pair["score"].item())    

df = pd.DataFrame.from_dict(dict_).sort_values(by=['scores'], ascending=False)
df.head(60)
# Out:
#                                                                   sent1  ...    scores
# 0                                Chronological Resume Tips and Examples  ...  0.938358
# 1          Resignation Letter Due to a Career Change: Tips and Examples  ...  0.929564
# 2              What Does "Business Casual" Mean? (With Example Outfits)  ...  0.913917
# 3                              Guide To Business Attire (With Examples)  ...  0.907581
# 4                      Here's Everything You Should Include on a Resume  ...  0.896563
# 5                         10 Resume Writing Tips To Help You Land a Job  ...  0.893672
# 6                         10 Resume Writing Tips To Help You Land a Job  ...  0.890749
# 7                         10 Resume Writing Tips To Help You Land a Job  ...  0.881679
# 8                     6 Universal Rules for Resume Writing (With Video)  ...  0.880301
# 9                      Here's Everything You Should Include on a Resume  ...  0.878379
# 10                              How to Make a Resume for Your First Job  ...  0.877741
# 11                             Guide To Business Attire (With Examples)  ...  0.877062
# 12                           Management Skills: Definition and Examples  ...  0.873539
# 13                                  Best Careers for ESFJ Personalities  ...  0.872239
# 14                          How to Write a Resume Employers Will Notice  ...  0.871935
# 15                       Listing Professional Experience on Your Resume  ...  0.870065
# 16     How to Write a Letter of Intent (With Examples and Writing Tips)  ...  0.867438
# 17                    6 Universal Rules for Resume Writing (With Video)  ...  0.866318
# 18                                       The Essential Job Search Guide  ...  0.865042
# 19                                Guide: How To Get a Job After College  ...  0.863134
# 20                    6 Universal Rules for Resume Writing (With Video)  ...  0.860948
# 21  How to Write a Letter of Recommendation (With Template and Example)  ...  0.858884
# 22                                    How To List Education on a Resume  ...  0.855944
# 23                    6 Universal Rules for Resume Writing (With Video)  ...  0.855302
# 24                          Technical Resume Writing: Tips and Examples  ...  0.852649
# 25                          How to Write a Resume Employers Will Notice  ...  0.850264
# 26                          Technical Resume Writing: Tips and Examples  ...  0.848331
# 27                                       The Essential Job Search Guide  ...  0.848051
# 28                                  Best Careers for ENFP Personalities  ...  0.847051
# 29                                    17 of the Best Self-Employed Jobs  ...  0.845917
# 30                        Letter of Recommendation for College Students  ...  0.844539
# 31                                 How to Make a Resume (With Examples)  ...  0.839836
# 32                       Listing Professional Experience on Your Resume  ...  0.836126
# 33                          Technical Resume Writing: Tips and Examples  ...  0.832804
# 34  How to Write a Letter of Recommendation (With Template and Example)  ...  0.831305
# 35                       Listing Professional Experience on Your Resume  ...  0.831247
# 36                21 Job Interview Tips: How To Make a Great Impression  ...  0.830277
# 37                 Interview Question: "Why Are You Looking for a Job?"  ...  0.828970
# 38        How to Explain Your Reasons for Leaving a Job (With Examples)  ...  0.827253
# 39                                    How To List Education on a Resume  ...  0.821691
# 40                            Computer Skills: Definitions and Examples  ...  0.821299
# 41                    6 Universal Rules for Resume Writing (With Video)  ...  0.820518
# 42                     Here's Everything You Should Include on a Resume  ...  0.819377
# 43                21 Job Interview Tips: How To Make a Great Impression  ...  0.818895
# 44                How to Format a Cover Letter (With Tips and Examples)  ...  0.818114
# 45                                Soft Skills: Definitions and Examples  ...  0.817953
# 46                       Listing Professional Experience on Your Resume  ...  0.813995
# 47             How To List Volunteer Work on Your Resume (With Example)  ...  0.813787
# 48                                         18 Top Economics Degree Jobs  ...  0.812935
# 49                         Human Resources: Definition and How It Works  ...  0.812303
# 50                       Listing Professional Experience on Your Resume  ...  0.812137
# 51    How to Answer "Tell Me About Yourself" (Tips and Example Answers)  ...  0.811961
# 52                21 Job Interview Tips: How To Make a Great Impression  ...  0.810984
# 53                                     9 College Resume Tips + Examples  ...  0.809908
# 54                        10 Resume Writing Tips To Help You Land a Job  ...  0.808886
# 55    How to Answer "Tell Me About Yourself" (Tips and Example Answers)  ...  0.808478
# 56                    6 Universal Rules for Resume Writing (With Video)  ...  0.808182
# 57                  15 Phone Interview Questions (With Example Answers)  ...  0.808143
# 58                   5 Questions To Ask Yourself Before a Job Interview  ...  0.806764
# 59                    6 Universal Rules for Resume Writing (With Video)  ...  0.805885
#
# [60 rows x 3 columns]

# %% [markdown]
# Comparison of the results with Link Data provided by Indeed and "msmarco-MiniLM-L-6-v3" model!
# --

# %%
from collections import defaultdict

path = "/content/drive/MyDrive/Copy of Pageview_matrix_20210511.csv"
links_not_found = set()
final_dict = defaultdict(list)
fout = open(path, "r")
fout.readline()
for line in fout:
    if line!="\n":
        try:
            line = line.split(",")
            url =  line[0].split("/")[-1]
            if url not in art_train["urlRoute"].values:
                if url not in cp_train["urlRoute"].values:
                    if url not in cl_train["urlRoute"].values:
                        if url not in res_train["urlRoute"].values:
                            links_not_found.add(line[0])
                        else:
                            sent1 = res_train[res_train["urlRoute"]==url]
                            sent1 = sent1["title"].values[0]
                    else:
                        sent1 = cl_train[cl_train["urlRoute"]==url]
                        sent1 = sent1["title"].values[0]
                else:
                    sent1 = cp_train[cp_train["urlRoute"]==url]
                    sent1 = sent1["h1"].values[0]
            else:
                sent1 = art_train[art_train["urlRoute"]==url]
                sent1 = sent1["contentTitle"].values[0]

            url =  line[1].split("/")[-1]
            if url not in art_train["urlRoute"].values:
                if url not in cp_train["urlRoute"].values:
                    if url not in cl_train["urlRoute"].values:
                        if url not in res_train["urlRoute"].values:
                            links_not_found.add(line[1])
                        else:
                            sent2 = res_train[res_train["urlRoute"]==url]
                            sent2 = sent2["title"].values[0]
                    else:
                        sent2 = cl_train[cl_train["urlRoute"]==url]
                        sent2 = sent2["title"].values[0]
                else:
                    sent2 = cp_train[cp_train["urlRoute"]==url]
                    sent2 = sent2["h1"].values[0]
            else:
                sent2 = art_train[art_train["urlRoute"]==url]
                sent2 = sent2["contentTitle"].values[0] 

            final_dict["sent1"].append(sent1)
            final_dict["sent2"].append(sent2)
            final_dict["visit"].append(int(line[2].replace("\n","")))
        except IndexError:
            print(line)

# %%
title1=list(art_train['contentTitle'])[:200]
cont =list(art_train['content'])[:200]
from sentence_transformers import SentenceTransformer, util
model = SentenceTransformer('msmarco-MiniLM-L-6-v3')
embeddings1 = model.encode(cont, convert_to_tensor=True) 
cosine_scores = util.pytorch_cos_sim(embeddings1, embeddings1)

pairs = []
for i in range(len(cosine_scores)-1):
    for j in range(i+1, len(cosine_scores)):
        pairs.append({'index': [i, j], 'score': cosine_scores[i][j]})

import pandas as pd
from collections import defaultdict

pairs = sorted(pairs, key=lambda x: x['score'], reverse=True)
dict_ = defaultdict(list)

for pair in pairs:
    i, j = pair['index']

    dict_["sent1"].append(title1[i]) 
    dict_["sent2"].append(title1[j])
    dict_["scores"].append(pair["score"].item())    

final_df = pd.DataFrame.from_dict(dict_).sort_values(by=['scores'], ascending=False)

# %%
link_df = pd.DataFrame.from_dict(final_dict).sort_values(by=['visit'], ascending=False)
link_df.head(60)
# Out:
#                                                      sent1  ... visit
# 0     List of Weaknesses: 10 Things To Say in an Interview  ...  2083
# 2     List of Weaknesses: 10 Things To Say in an Interview  ...   322
# 25    List of Weaknesses: 10 Things To Say in an Interview  ...   116
# 86    List of Weaknesses: 10 Things To Say in an Interview  ...    65
# 93    List of Weaknesses: 10 Things To Say in an Interview  ...    63
# 104   List of Weaknesses: 10 Things To Say in an Interview  ...    57
# 123   List of Weaknesses: 10 Things To Say in an Interview  ...    53
# 125   List of Weaknesses: 10 Things To Say in an Interview  ...    52
# 143   List of Weaknesses: 10 Things To Say in an Interview  ...    48
# 155   List of Weaknesses: 10 Things To Say in an Interview  ...    46
# 183   List of Weaknesses: 10 Things To Say in an Interview  ...    42
# 184   List of Weaknesses: 10 Things To Say in an Interview  ...    42
# 191   List of Weaknesses: 10 Things To Say in an Interview  ...    41
# 201   List of Weaknesses: 10 Things To Say in an Interview  ...    40
# 200   List of Weaknesses: 10 Things To Say in an Interview  ...    40
# 277   List of Weaknesses: 10 Things To Say in an Interview  ...    34
# 307   List of Weaknesses: 10 Things To Say in an Interview  ...    32
# 297   List of Weaknesses: 10 Things To Say in an Interview  ...    32
# 315   List of Weaknesses: 10 Things To Say in an Interview  ...    31
# 314   List of Weaknesses: 10 Things To Say in an Interview  ...    31
# 331   List of Weaknesses: 10 Things To Say in an Interview  ...    30
# 327   List of Weaknesses: 10 Things To Say in an Interview  ...    30
# 325   List of Weaknesses: 10 Things To Say in an Interview  ...    30
# 320   List of Weaknesses: 10 Things To Say in an Interview  ...    30
# 390   List of Weaknesses: 10 Things To Say in an Interview  ...    27
# 446   List of Weaknesses: 10 Things To Say in an Interview  ...    25
# 472   List of Weaknesses: 10 Things To Say in an Interview  ...    24
# 493   List of Weaknesses: 10 Things To Say in an Interview  ...    23
# 571   List of Weaknesses: 10 Things To Say in an Interview  ...    21
# 625   List of Weaknesses: 10 Things To Say in an Interview  ...    20
# 632   List of Weaknesses: 10 Things To Say in an Interview  ...    20
# 677   List of Weaknesses: 10 Things To Say in an Interview  ...    19
# 687   List of Weaknesses: 10 Things To Say in an Interview  ...    19
# 661   List of Weaknesses: 10 Things To Say in an Interview  ...    19
# 811   List of Weaknesses: 10 Things To Say in an Interview  ...    17
# 813   List of Weaknesses: 10 Things To Say in an Interview  ...    17
# 828   List of Weaknesses: 10 Things To Say in an Interview  ...    17
# 792   List of Weaknesses: 10 Things To Say in an Interview  ...    17
# 889   List of Weaknesses: 10 Things To Say in an Interview  ...    16
# 912   List of Weaknesses: 10 Things To Say in an Interview  ...    16
# 896   List of Weaknesses: 10 Things To Say in an Interview  ...    16
# 857   List of Weaknesses: 10 Things To Say in an Interview  ...    16
# 995   List of Weaknesses: 10 Things To Say in an Interview  ...    15
# 939   List of Weaknesses: 10 Things To Say in an Interview  ...    15
# 1112  List of Weaknesses: 10 Things To Say in an Interview  ...    14
# 1252  List of Weaknesses: 10 Things To Say in an Interview  ...    13
# 1164  List of Weaknesses: 10 Things To Say in an Interview  ...    13
# 1165  List of Weaknesses: 10 Things To Say in an Interview  ...    13
# 1195  List of Weaknesses: 10 Things To Say in an Interview  ...    13
# 1192  List of Weaknesses: 10 Things To Say in an Interview  ...    13
# 1438  List of Weaknesses: 10 Things To Say in an Interview  ...    12
# 1656  List of Weaknesses: 10 Things To Say in an Interview  ...    11
# 1527  List of Weaknesses: 10 Things To Say in an Interview  ...    11
# 1536  List of Weaknesses: 10 Things To Say in an Interview  ...    11
# 1506  List of Weaknesses: 10 Things To Say in an Interview  ...    11
# 1587  List of Weaknesses: 10 Things To Say in an Interview  ...    11
# 2012  List of Weaknesses: 10 Things To Say in an Interview  ...    10
# 2003  List of Weaknesses: 10 Things To Say in an Interview  ...    10
# 1940  List of Weaknesses: 10 Things To Say in an Interview  ...    10
# 1935  List of Weaknesses: 10 Things To Say in an Interview  ...    10
#
# [60 rows x 3 columns]

# %%
final_df[final_df["sent2"]=="List of Weaknesses: 10 Things To Say in an Interview"].head(60)
# Out:
#                                                                        sent1  ...    scores
# 160                39 Strengths and Weaknesses to Discuss in a Job Interview  ...  0.754508
# 250        How to Answer "Tell Me About Yourself" (Tips and Example Answers)  ...  0.726102
# 458                                          How To Prepare for an Interview  ...  0.686610
# 579              14 Common Second Interview Questions (With Example Answers)  ...  0.669918
# 598                         Problem-Solving Skills: Definitions and Examples  ...  0.667006
# 624                    21 Job Interview Tips: How To Make a Great Impression  ...  0.663864
# 632                                 12 Tough Interview Questions and Answers  ...  0.662564
# 661   Interview Question: "How Would You Describe Yourself?" (With Examples)  ...  0.659704
# 693                 5 Situational Interview Questions (With Example Answers)  ...  0.656247
# 1136                  125 Common Interview Questions and Answers (With Tips)  ...  0.616720
# 1180           How to Explain Your Reasons for Leaving a Job (With Examples)  ...  0.613423
# 1211                                 Communication Skills for Career Success  ...  0.611550
# 1289                8 Common Exit Interview Questions (With Example Answers)  ...  0.607244
# 1311                  Video Interview Guide: Tips for a Successful Interview  ...  0.605853
# 1331                           Collaboration Skills: Definition and Examples  ...  0.604521
# 1391                Interview Question: "What Are Your Salary Expectations?"  ...  0.601527
# 1488                                  The New Graduate's Guide To Job Search  ...  0.596448
# 1617                                                   How To Change Careers  ...  0.590070
# 1727                                    How to Deal With Job Dissatisfaction  ...  0.584793
# 1730                               How to Introduce Yourself in an Interview  ...  0.584756
# 1745                                          The Essential Job Search Guide  ...  0.584069
# 1746                                           Guide: How To Choose a Career  ...  0.584048
# 1804                                      The Definitive Guide To Mentorship  ...  0.580815
# 1981                            10 Ways To Get the Most From Your Internship  ...  0.573415
# 2064                             Analytical Skills: Definitions and Examples  ...  0.570132
# 2139                          Listing Professional Experience on Your Resume  ...  0.567060
# 2144                                       Informational Interview Questions  ...  0.566911
# 2195                                   Where Do You See Yourself in 5 Years?  ...  0.565049
# 2273                             How to Write a Resume Employers Will Notice  ...  0.562051
# 2397                                 How to Make a Resume for Your First Job  ...  0.556949
# 2446                     15 Phone Interview Questions (With Example Answers)  ...  0.555584
# 2503                             Leadership Skills: Definitions and Examples  ...  0.553858
# 2512                           Email Examples: How To Respond To a Recruiter  ...  0.553533
# 2525                       6 Universal Rules for Resume Writing (With Video)  ...  0.552934
# 2611                                     SWOT Analysis Guide (With Examples)  ...  0.549588
# 2660                                             15 Best Jobs for Introverts  ...  0.547767
# 2807               Character Trait Examples: Best Traits for Work and Resume  ...  0.542662
# 2871                                                How To Be a Good Manager  ...  0.540473
# 2875                                      How to Empower Yourself and Others  ...  0.540358
# 2944           Job Search Guide: Product Management and Software Engineering  ...  0.538339
# 2946                        How To Use the STAR Interview Response Technique  ...  0.538218
# 3112                           How To Give an Elevator Pitch (With Examples)  ...  0.533422
# 3413                           10 Resume Writing Tips To Help You Land a Job  ...  0.523874
# 3522                              Management Skills: Definition and Examples  ...  0.520122
# 3604                                          Tips to Demonstrate Work Ethic  ...  0.517861
# 3608                                          What To Do After Getting Fired  ...  0.517793
# 3692                          Interpersonal Skills: Definitions and Examples  ...  0.515404
# 3763                     Conflict Resolution Skills: Definition and Examples  ...  0.513624
# 3778                                        9 College Resume Tips + Examples  ...  0.513023
# 3992                            Job Search Guide for Former Military Members  ...  0.507262
# 4021                      The Importance of Cognitive Ability in Your Career  ...  0.506666
# 4110    What Happens To My Resume After I Click Apply? Plus Tips for Success  ...  0.504382
# 4140                        Follow-Up Email Examples For After the Interview  ...  0.503542
# 4231           What Is Inductive Reasoning? (Plus Examples of How to Use It)  ...  0.501054
# 4255                             The Complete Guide to Researching a Company  ...  0.500470
# 4287                                       Ultimate Guide to Professionalism  ...  0.500043
# 4391                                       Work-From-Home Jobs That Pay Well  ...  0.497374
# 4652                    Customer Service Skills: Definitions and 17 Examples  ...  0.490312
# 4731                      Writing an Internship Cover Letter (With Examples)  ...  0.488403
# 4735                              Technical Skills: Definitions and Examples  ...  0.488307
#
# [60 rows x 3 columns]

# %%
link_df[link_df["sent1"]=="125 Common Interview Questions and Answers (With Tips)"].head(60)
# Out:
#                                                       sent1  ... visit
# 1    125 Common Interview Questions and Answers (With Tips)  ...   428
# 3    125 Common Interview Questions and Answers (With Tips)  ...   307
# 4    125 Common Interview Questions and Answers (With Tips)  ...   295
# 6    125 Common Interview Questions and Answers (With Tips)  ...   274
# 10   125 Common Interview Questions and Answers (With Tips)  ...   177
# 26   125 Common Interview Questions and Answers (With Tips)  ...   115
# 29   125 Common Interview Questions and Answers (With Tips)  ...   110
# 32   125 Common Interview Questions and Answers (With Tips)  ...   103
# 37   125 Common Interview Questions and Answers (With Tips)  ...    99
# 49   125 Common Interview Questions and Answers (With Tips)  ...    89
# 53   125 Common Interview Questions and Answers (With Tips)  ...    84
# 56   125 Common Interview Questions and Answers (With Tips)  ...    81
# 61   125 Common Interview Questions and Answers (With Tips)  ...    77
# 63   125 Common Interview Questions and Answers (With Tips)  ...    75
# 67   125 Common Interview Questions and Answers (With Tips)  ...    71
# 68   125 Common Interview Questions and Answers (With Tips)  ...    71
# 80   125 Common Interview Questions and Answers (With Tips)  ...    67
# 91   125 Common Interview Questions and Answers (With Tips)  ...    64
# 101  125 Common Interview Questions and Answers (With Tips)  ...    59
# 106  125 Common Interview Questions and Answers (With Tips)  ...    57
# 112  125 Common Interview Questions and Answers (With Tips)  ...    56
# 150  125 Common Interview Questions and Answers (With Tips)  ...    47
# 147  125 Common Interview Questions and Answers (With Tips)  ...    47
# 157  125 Common Interview Questions and Answers (With Tips)  ...    46
# 158  125 Common Interview Questions and Answers (With Tips)  ...    45
# 159  125 Common Interview Questions and Answers (With Tips)  ...    45
# 192  125 Common Interview Questions and Answers (With Tips)  ...    40
# 220  125 Common Interview Questions and Answers (With Tips)  ...    38
# 217  125 Common Interview Questions and Answers (With Tips)  ...    38
# 215  125 Common Interview Questions and Answers (With Tips)  ...    38
# 237  125 Common Interview Questions and Answers (With Tips)  ...    37
# 247  125 Common Interview Questions and Answers (With Tips)  ...    36
# 278  125 Common Interview Questions and Answers (With Tips)  ...    34
# 317  125 Common Interview Questions and Answers (With Tips)  ...    31
# 323  125 Common Interview Questions and Answers (With Tips)  ...    30
# 322  125 Common Interview Questions and Answers (With Tips)  ...    30
# 339  125 Common Interview Questions and Answers (With Tips)  ...    29
# 342  125 Common Interview Questions and Answers (With Tips)  ...    29
# 384  125 Common Interview Questions and Answers (With Tips)  ...    28
# 367  125 Common Interview Questions and Answers (With Tips)  ...    28
# 405  125 Common Interview Questions and Answers (With Tips)  ...    27
# 418  125 Common Interview Questions and Answers (With Tips)  ...    26
# 469  125 Common Interview Questions and Answers (With Tips)  ...    24
# 474  125 Common Interview Questions and Answers (With Tips)  ...    24
# 489  125 Common Interview Questions and Answers (With Tips)  ...    23
# 537  125 Common Interview Questions and Answers (With Tips)  ...    22
# 540  125 Common Interview Questions and Answers (With Tips)  ...    22
# 577  125 Common Interview Questions and Answers (With Tips)  ...    21
# 548  125 Common Interview Questions and Answers (With Tips)  ...    21
# 603  125 Common Interview Questions and Answers (With Tips)  ...    20
# 686  125 Common Interview Questions and Answers (With Tips)  ...    19
# 653  125 Common Interview Questions and Answers (With Tips)  ...    19
# 647  125 Common Interview Questions and Answers (With Tips)  ...    19
# 655  125 Common Interview Questions and Answers (With Tips)  ...    19
# 665  125 Common Interview Questions and Answers (With Tips)  ...    19
# 756  125 Common Interview Questions and Answers (With Tips)  ...    18
# 706  125 Common Interview Questions and Answers (With Tips)  ...    18
# 718  125 Common Interview Questions and Answers (With Tips)  ...    18
# 715  125 Common Interview Questions and Answers (With Tips)  ...    18
# 802  125 Common Interview Questions and Answers (With Tips)  ...    17
#
# [60 rows x 3 columns]

# %%
final_df[final_df["sent2"]=="125 Common Interview Questions and Answers (With Tips)"].head(60)
# Out:
#                                                                      sent1  ...    scores
# 68                   21 Job Interview Tips: How To Make a Great Impression  ...  0.800237
# 204                               12 Tough Interview Questions and Answers  ...  0.739717
# 206      How to Answer "Tell Me About Yourself" (Tips and Example Answers)  ...  0.739399
# 211                    15 Phone Interview Questions (With Example Answers)  ...  0.737007
# 339                              How to Introduce Yourself in an Interview  ...  0.707659
# 385        Email Examples: How to Respond to an Employer Interview Request  ...  0.698295
# 545              39 Strengths and Weaknesses to Discuss in a Job Interview  ...  0.675285
# 855                          10 Resume Writing Tips To Help You Land a Job  ...  0.639319
# 865              Guide: How to Succeed at a Hiring Event or Open Interview  ...  0.638334
# 910                       Follow-Up Email Examples For After the Interview  ...  0.634134
# 1315                           How to Write a Resume Employers Will Notice  ...  0.605913
# 1385                     6 Universal Rules for Resume Writing (With Video)  ...  0.602201
# 1439                      How To Use the STAR Interview Response Technique  ...  0.599413
# 1442         How to Explain Your Reasons for Leaving a Job (With Examples)  ...  0.599374
# 1489                                      9 College Resume Tips + Examples  ...  0.597110
# 1527                               Communication Skills for Career Success  ...  0.594788
# 1574                      Here's Everything You Should Include on a Resume  ...  0.592568
# 1858                                     How To List Education on a Resume  ...  0.578716
# 1879         Job Search Guide: Product Management and Software Engineering  ...  0.577910
# 1891                        Listing Professional Experience on Your Resume  ...  0.577488
# 2059                                         Guide: How To Choose a Career  ...  0.570806
# 2173                         How to Ask for a Raise (With Script Examples)  ...  0.566161
# 2179              8 Common Exit Interview Questions (With Example Answers)  ...  0.566012
# 2186                           Technical Resume Writing: Tips and Examples  ...  0.565774
# 2238                                   How To Succeed at a Group Interview  ...  0.563717
# 2246                         Email Examples: How To Respond To a Recruiter  ...  0.563379
# 2577              Interview Question: "What Are Your Salary Expectations?"  ...  0.550938
# 2612                                        The Essential Job Search Guide  ...  0.549648
# 2641              How To List Volunteer Work on Your Resume (With Example)  ...  0.548548
# 2847  What Happens To My Resume After I Click Apply? Plus Tips for Success  ...  0.541236
# 2950                                                 How To Change Careers  ...  0.538114
# 3231                        Interpersonal Skills: Definitions and Examples  ...  0.529721
# 3389                      Problem-Solving Skills: Definitions and Examples  ...  0.524998
# 3427                         Collaboration Skills: Definition and Examples  ...  0.523935
# 3517                                           15 Best Jobs for Introverts  ...  0.521063
# 3939                    Writing an Internship Cover Letter (With Examples)  ...  0.508798
# 4122                                How To Show a Promotion on Your Resume  ...  0.504340
# 4227                               How to Create a Resume Template in Word  ...  0.501540
# 4295   How to Write a Letter of Recommendation (With Template and Example)  ...  0.500116
# 4470                       When to Use the Phrase "To Whom It May Concern"  ...  0.495739
# 4579                          10 Ways To Get the Most From Your Internship  ...  0.492920
# 4837                           The Complete Guide to Researching a Company  ...  0.486190
# 4867                  Customer Service Skills: Definitions and 17 Examples  ...  0.485486
# 4916                         How To Give an Elevator Pitch (With Examples)  ...  0.484478
# 5106                        13 Tips to Negotiate Your Salary and Job Offer  ...  0.480671
# 5139                                   High School Resume Tips and Example  ...  0.479986
# 5261                                  How to Deal With Job Dissatisfaction  ...  0.476385
# 5282                                 Guide: How To Get a Job After College  ...  0.475987
# 5534                         Letter of Recommendation for College Students  ...  0.470891
# 5676           Curriculum Vitae (CV) Format Guide (With Examples and Tips)  ...  0.468057
# 5698                                              Guide To Thank You Notes  ...  0.467418
# 5963                            20 Side Jobs To Generate Additional Income  ...  0.461820
# 6161                            Management Skills: Definition and Examples  ...  0.457434
# 6359                                Icebreaker Activities for a Work Event  ...  0.452744
# 6374         What Is Inductive Reasoning? (Plus Examples of How to Use It)  ...  0.452464
# 6806                                        What To Do After Getting Fired  ...  0.444316
# 7196                                     17 of the Best Self-Employed Jobs  ...  0.437148
# 7374                                     Work-From-Home Jobs That Pay Well  ...  0.433811
# 7496                                  Combination Resume Tips and Examples  ...  0.431751
# 7626                              Guide To Business Attire (With Examples)  ...  0.429211
#
# [60 rows x 3 columns]

# %%
link_df[link_df["sent1"]=="39 Strengths and Weaknesses to Discuss in a Job Interview"].head(60)
# Out:
#                                                           sent1  ... visit
# 5     39 Strengths and Weaknesses to Discuss in a Job Interview  ...   281
# 27    39 Strengths and Weaknesses to Discuss in a Job Interview  ...   111
# 82    39 Strengths and Weaknesses to Discuss in a Job Interview  ...    67
# 100   39 Strengths and Weaknesses to Discuss in a Job Interview  ...    61
# 127   39 Strengths and Weaknesses to Discuss in a Job Interview  ...    51
# 134   39 Strengths and Weaknesses to Discuss in a Job Interview  ...    50
# 142   39 Strengths and Weaknesses to Discuss in a Job Interview  ...    48
# 210   39 Strengths and Weaknesses to Discuss in a Job Interview  ...    39
# 225   39 Strengths and Weaknesses to Discuss in a Job Interview  ...    38
# 273   39 Strengths and Weaknesses to Discuss in a Job Interview  ...    34
# 294   39 Strengths and Weaknesses to Discuss in a Job Interview  ...    33
# 306   39 Strengths and Weaknesses to Discuss in a Job Interview  ...    32
# 296   39 Strengths and Weaknesses to Discuss in a Job Interview  ...    32
# 372   39 Strengths and Weaknesses to Discuss in a Job Interview  ...    28
# 461   39 Strengths and Weaknesses to Discuss in a Job Interview  ...    24
# 463   39 Strengths and Weaknesses to Discuss in a Job Interview  ...    24
# 483   39 Strengths and Weaknesses to Discuss in a Job Interview  ...    23
# 487   39 Strengths and Weaknesses to Discuss in a Job Interview  ...    23
# 492   39 Strengths and Weaknesses to Discuss in a Job Interview  ...    23
# 517   39 Strengths and Weaknesses to Discuss in a Job Interview  ...    22
# 622   39 Strengths and Weaknesses to Discuss in a Job Interview  ...    20
# 679   39 Strengths and Weaknesses to Discuss in a Job Interview  ...    19
# 673   39 Strengths and Weaknesses to Discuss in a Job Interview  ...    19
# 839   39 Strengths and Weaknesses to Discuss in a Job Interview  ...    16
# 989   39 Strengths and Weaknesses to Discuss in a Job Interview  ...    15
# 1009  39 Strengths and Weaknesses to Discuss in a Job Interview  ...    15
# 1004  39 Strengths and Weaknesses to Discuss in a Job Interview  ...    15
# 1057  39 Strengths and Weaknesses to Discuss in a Job Interview  ...    14
# 1230  39 Strengths and Weaknesses to Discuss in a Job Interview  ...    13
# 1157  39 Strengths and Weaknesses to Discuss in a Job Interview  ...    13
# 1208  39 Strengths and Weaknesses to Discuss in a Job Interview  ...    13
# 1455  39 Strengths and Weaknesses to Discuss in a Job Interview  ...    12
# 1391  39 Strengths and Weaknesses to Discuss in a Job Interview  ...    12
# 1331  39 Strengths and Weaknesses to Discuss in a Job Interview  ...    12
# 1684  39 Strengths and Weaknesses to Discuss in a Job Interview  ...    11
# 1542  39 Strengths and Weaknesses to Discuss in a Job Interview  ...    11
# 1509  39 Strengths and Weaknesses to Discuss in a Job Interview  ...    11
# 1605  39 Strengths and Weaknesses to Discuss in a Job Interview  ...    11
# 2074  39 Strengths and Weaknesses to Discuss in a Job Interview  ...    10
# 2107  39 Strengths and Weaknesses to Discuss in a Job Interview  ...    10
# 1792  39 Strengths and Weaknesses to Discuss in a Job Interview  ...    10
# 1765  39 Strengths and Weaknesses to Discuss in a Job Interview  ...    10
# 1919  39 Strengths and Weaknesses to Discuss in a Job Interview  ...    10
# 1907  39 Strengths and Weaknesses to Discuss in a Job Interview  ...    10
# 2433  39 Strengths and Weaknesses to Discuss in a Job Interview  ...     9
# 2479  39 Strengths and Weaknesses to Discuss in a Job Interview  ...     9
# 2553  39 Strengths and Weaknesses to Discuss in a Job Interview  ...     9
# 2582  39 Strengths and Weaknesses to Discuss in a Job Interview  ...     9
# 2609  39 Strengths and Weaknesses to Discuss in a Job Interview  ...     9
# 2587  39 Strengths and Weaknesses to Discuss in a Job Interview  ...     9
# 2552  39 Strengths and Weaknesses to Discuss in a Job Interview  ...     9
# 2533  39 Strengths and Weaknesses to Discuss in a Job Interview  ...     9
# 2150  39 Strengths and Weaknesses to Discuss in a Job Interview  ...     9
# 2322  39 Strengths and Weaknesses to Discuss in a Job Interview  ...     9
# 2340  39 Strengths and Weaknesses to Discuss in a Job Interview  ...     9
# 2261  39 Strengths and Weaknesses to Discuss in a Job Interview  ...     9
# 2260  39 Strengths and Weaknesses to Discuss in a Job Interview  ...     9
# 2296  39 Strengths and Weaknesses to Discuss in a Job Interview  ...     9
# 2293  39 Strengths and Weaknesses to Discuss in a Job Interview  ...     9
# 3172  39 Strengths and Weaknesses to Discuss in a Job Interview  ...     8
#
# [60 rows x 3 columns]

# %%
final_df[final_df["sent2"]=="39 Strengths and Weaknesses to Discuss in a Job Interview"].head(60)
# Out:
#                                                                          sent1  ...    scores
# 639                                How to Write a Resume Employers Will Notice  ...  0.661646
# 745                          6 Universal Rules for Resume Writing (With Video)  ...  0.649263
# 872                              10 Resume Writing Tips To Help You Land a Job  ...  0.637309
# 889                        15 Phone Interview Questions (With Example Answers)  ...  0.636109
# 1155                                             Guide: How To Choose a Career  ...  0.615863
# 1261                                 How to Introduce Yourself in an Interview  ...  0.609409
# 1337                  Interview Question: "What Are Your Salary Expectations?"  ...  0.604740
# 1446                                               15 Best Jobs for Introverts  ...  0.599167
# 1456                            Listing Professional Experience on Your Resume  ...  0.598745
# 1538                                Management Skills: Definition and Examples  ...  0.594070
# 1947                          Problem-Solving Skills: Definitions and Examples  ...  0.574802
# 2067                               Technical Resume Writing: Tips and Examples  ...  0.570449
# 2300                                   How to Create a Resume Template in Word  ...  0.561271
# 2354                                                     How To Change Careers  ...  0.559317
# 2567                             Collaboration Skills: Definition and Examples  ...  0.551184
# 2761                  8 Common Exit Interview Questions (With Example Answers)  ...  0.544123
# 2868                                            What To Do After Getting Fired  ...  0.540515
# 2906                            Interpersonal Skills: Definitions and Examples  ...  0.539331
# 3088                                            The Essential Job Search Guide  ...  0.534394
# 3259                                   Communication Skills for Career Success  ...  0.528770
# 3606                             How To Give an Elevator Pitch (With Examples)  ...  0.518469
# 3995       How to Write a Letter of Recommendation (With Template and Example)  ...  0.507567
# 4613                                        How to Empower Yourself and Others  ...  0.492114
# 5081               Curriculum Vitae (CV) Format Guide (With Examples and Tips)  ...  0.481118
# 5226                        Writing an Internship Cover Letter (With Examples)  ...  0.477672
# 5296                                       High School Resume Tips and Example  ...  0.475674
# 5592      What Happens To My Resume After I Click Apply? Plus Tips for Success  ...  0.469696
# 5617           Email Examples: How to Respond to an Employer Interview Request  ...  0.469213
# 5724                             Using Performance Management in the Workplace  ...  0.466819
# 6158                          How To Use the STAR Interview Response Technique  ...  0.457481
# 6304              Resignation Letter Due to a Career Change: Tips and Examples  ...  0.454222
# 6336                        Becoming a Manager: How To Develop a Work Schedule  ...  0.453456
# 6514                            13 Tips to Negotiate Your Salary and Job Offer  ...  0.449797
# 6585                                           15 Marketing Jobs That Pay Well  ...  0.448716
# 6720             What Is Inductive Reasoning? (Plus Examples of How to Use It)  ...  0.445984
# 7239                                                        Jobs That Pay Well  ...  0.436316
# 7407                        The Importance of Cognitive Ability in Your Career  ...  0.433056
# 7452                                         17 of the Best Self-Employed Jobs  ...  0.432393
# 8259                             How to Ask for a Raise (With Script Examples)  ...  0.417436
# 8447                          Functional Resume: Definition, Tips and Examples  ...  0.414175
# 9346                                       How To Succeed at a Group Interview  ...  0.398740
# 9672   Career Advice for Service Members: Making a Transition To Civilian Life  ...  0.393461
# 9923                              Human Resources: Definition and How It Works  ...  0.389432
# 10028                                                          Low Stress Jobs  ...  0.387885
# 10567                                                     9 Popular Trade Jobs  ...  0.379609
# 10633                            25 Career Options for Former Military Members  ...  0.378280
# 10862                                              14 Sales Jobs That Pay Well  ...  0.374567
# 11403                                 How To Build Business Development Skills  ...  0.365592
# 11485                             Guide To Succession Planning and Your Career  ...  0.364410
# 12339                                             10 Highest Paid Nursing Jobs  ...  0.350871
# 12493                                              10 Summer Jobs for Teachers  ...  0.348331
# 12717                               What Is the Occupational Outlook Handbook?  ...  0.344280
# 12801                                                   11 Popular Travel Jobs  ...  0.342809
# 13182                                   Chronological Resume Tips and Examples  ...  0.336155
# 13213                                      Best Careers for ISTJ Personalities  ...  0.335656
# 13699                                   Learning Styles for Career Development  ...  0.327248
# 14902                Critical Path Project Management: Definition and Examples  ...  0.304600
# 15613                                        12 Health Care Jobs That Pay Well  ...  0.290118
# 16002                                         15 Popular Chemistry Degree Jobs  ...  0.281839
# 16132                                 Guide To Business Attire (With Examples)  ...  0.278921
#
# [60 rows x 3 columns]

# %% [markdown]
# Performing Kendall tau to check if relative pairwise ranking predicted by the links is preserved in the ranking coming from the model
# --

# %%
golds = set(link_df["sent1"].values)
systems = set(final_df["sent2"].values)

# %%
from scipy.stats import kendalltau
results = defaultdict(float)

for gold in golds:
    if gold in systems:
        final = model.encode(link_df[link_df["sent1"]==gold]["sent2"].values[0], convert_to_tensor=True)
        to_check = model.encode(final_df[final_df["sent2"]==gold]["sent1"].values[0], convert_to_tensor=True)
        kt = kendalltau(final.cpu(), to_check.cpu())[0]
        results[gold] = kt

# %%
import operator

sorted_tuples = sorted(results.items(), key=operator.itemgetter(1))[::-1]

# %%
sorted_tuples
# Out:
# [('How To Ask for a Letter of Recommendation (With Examples)', 1.0),
#  ('List of Weaknesses: 10 Things To Say in an Interview', 1.0),
#  ('7 Powerful Ways to Start a Cover Letter (With Examples)', 1.0),
#  ('125 Common Interview Questions and Answers (With Tips)', 1.0),
#  ('Best Careers for INFP Personalities', 1.0),
#  ('Letter of Recommendation for College Students', 1.0),
#  ('What Does "Business Casual" Mean? (With Example Outfits)', 1.0),
#  ('Video Interview Guide: Tips for a Successful Interview', 1.0),
#  ('Guide to Gender Neutral Attire', 0.7363468233246301),
#  ('How To Write a Resignation Letter (With Samples and Tips)',
#   0.5741405570060922),
#  ('10 Ways To Get the Most From Your Internship', 0.5520833333333333),
#  ('12 Tough Interview Questions and Answers', 0.5054939077458659),
#  ('Resume Objectives: 70+ Examples and Tips', 0.47076261966927757),
#  ('How to Make a Resume (With Examples)', 0.4505820278503046),
#  ('Low Stress Jobs', 0.43877828546562225),
#  ('2021’s Top Resume Formats: Tips and Examples of Three Common Resumes',
#   0.4270833333333333),
#  ('How to Format a Cover Letter (With Tips and Examples)', 0.4262674064403829),
#  ('Management Skills: Definition and Examples', 0.4128318102697998),
#  ('Interview Question: "What Makes You Unique?"', 0.4101664490861619),
#  ('9 College Resume Tips + Examples', 0.4081538294168842),
#  ('Customer Service Skills: Definitions and 17 Examples', 0.3999401653611836),
#  ('Communication Skills for Career Success', 0.3989882506527415),
#  ("Here's Everything You Should Include on a Resume", 0.3987706701479547),
#  ('Interview Question: "What Are Your Salary Expectations?"',
#   0.3965404699738903),
#  ('How To Write a Cover Letter (Plus Tips and Examples)', 0.393140774586597),
#  ('Letter of Recommendation for a Teacher', 0.38596061792863356),
#  ('15 Computer Science Jobs That Pay Well', 0.377203002610966),
#  ('9 Popular Trade Jobs', 0.375),
#  ('Combination Resume Tips and Examples', 0.36507288946910355),
#  ('Functional Resume: Definition, Tips and Examples', 0.3642841601392515),
#  ('Nonverbal Communication Skills: Definition and Examples',
#   0.3611292428198433),
#  ('15 Top Psychology Degree Jobs', 0.3590078328981723),
#  ('How To List Volunteer Work on Your Resume (With Example)',
#   0.35675043516100957),
#  ('Resignation Letter Due to a Career Change: Tips and Examples',
#   0.35555374238468235),
#  ('Technical Skills: Definitions and Examples', 0.352861183637946),
#  ('How To Use the STAR Interview Response Technique', 0.34894473455178415),
#  ('Soft Skills: Definitions and Examples', 0.34083986074847694),
#  ('Jobs That Pay Over $50k', 0.3393983899042645),
#  ('16 Top Communications Degree Jobs', 0.33189186248912095),
#  ('Computer Skills: Definitions and Examples', 0.32008812010443866),
#  ('Character Reference Letter Sample and Tips', 0.3192449956483899),
#  ('5 Questions To Ask Yourself Before a Job Interview', 0.3176131418624891),
#  ('14 Common Second Interview Questions (With Example Answers)',
#   0.3163892515230635),
#  ('How to Answer "What Is Your Teaching Philosophy?"', 0.3088283289817232),
#  ('15 Phone Interview Questions (With Example Answers)', 0.3073596605744125),
#  ('Letter of Interest: Definition, Tips and Examples', 0.30559181897301996),
#  ('How to Answer "Tell Me About Yourself" (Tips and Example Answers)',
#   0.3040143603133159),
#  ('Interview Question: "Why Do You Want To Be a Nurse?"', 0.30260008703220187),
#  ('Ultimate Guide to Professionalism', 0.30254569190600517),
#  ('How to Make a Resume for Your First Job', 0.3024640992167102),
#  ('17 of the Best Self-Employed Jobs', 0.3016209747606614),
#  ('20 Part-Time Jobs That Pay Well', 0.3012946040034813),
#  ('Guide To Updating Your Resume', 0.2989828111401219),
#  ('Social Skills: Definition and Examples', 0.28527523933855525),
#  ('Analytical Skills: Definitions and Examples', 0.2849760661444734),
#  ('How To Prepare for an Interview', 0.284078546562228),
#  ('Guide: How To Choose a Career', 0.28146758050478676),
#  ('How to Write a Letter of Intent (With Examples and Writing Tips)',
#   0.2809508268059182),
#  ('Listing Professional Experience on Your Resume', 0.279291775456919),
#  ('4 Types of Communication and How to Improve Them', 0.27901979982593555),
#  ('Interview Question: "Why Are You Looking for a Job?"', 0.27526653611836377),
#  ("The New Graduate's Guide To Job Search", 0.274967362924282),
#  ('10 Popular History Degree Jobs', 0.274967362924282),
#  ('21 Job Interview Tips: How To Make a Great Impression',
#   0.27219321148825065),
#  ('How To Write a Professional Email', 0.2706429503916449),
#  ('Email Examples: How to Respond to an Employer Interview Request',
#   0.2663185378590078),
#  ('How to Write a Letter of Recommendation (With Template and Example)',
#   0.26599216710182766),
#  ('Best Careers for ISFJ Personalities', 0.26487706701479546),
#  ('How to Write a Resume Employers Will Notice', 0.26397954743255003),
#  ('Where Do You See Yourself in 5 Years?', 0.26332680591818974),
#  ('Transformational Leadership: Definition and Examples', 0.26281005221932113),
#  ('Best Careers for ISTP Personalities', 0.2626196692776327),
#  ('13 Tips to Negotiate Your Salary and Job Offer', 0.2614773716275022),
#  ('Business Letter Format and Example', 0.26131418624891206),
#  ('Jobs That Pay Well', 0.2601446910356832),
#  ('How to Empower Yourself and Others', 0.2578057006092254),
#  ('Guide To Unemployment Benefits', 0.25473237597911225),
#  ('What Happens To My Resume After I Click Apply? Plus Tips for Success',
#   0.2511422976501306),
#  ('8 Common Exit Interview Questions (With Example Answers)',
#   0.24787859007832896),
#  ('The Definitive Guide To Mentorship', 0.24763381201044385),
#  ('Collaboration Skills: Definition and Examples', 0.24499564838990426),
#  ('5 Situational Interview Questions (With Example Answers)',
#   0.2393385552654482),
#  ('Learning Styles for Career Development', 0.23865861618798956),
#  ('The Complete Guide to Researching a Company', 0.23588446475195823),
#  ('Listing Hobbies and Interests on Your Resume (With Examples)',
#   0.2353405134899913),
#  ('How to Introduce Yourself in an Interview', 0.23392624020887726),
#  ('How to Deal With Job Dissatisfaction', 0.23351827676240208),
#  ('Writing an Internship Cover Letter (With Examples)', 0.23014577893820712),
#  ('15 Warehouse Jobs That Pay Well', 0.2300641862489121),
#  ('Problem-Solving Skills: Definitions and Examples', 0.22919386422976498),
#  ('Character Trait Examples: Best Traits for Work and Resume',
#   0.22481505657093123),
#  ('Guide: How To Get a Job After College', 0.22440709312445603),
#  ('Active Listening Skills: Definition and Examples', 0.22402632724107918),
#  ('When to Use the Phrase "To Whom It May Concern"', 0.2239175369886858),
#  ('Interview Question: "How Would You Describe Yourself?" (With Examples)',
#   0.22304721496953872),
#  ('Leadership Skills: Definitions and Examples', 0.2221496953872933),
#  ('Curriculum Vitae (CV) Format Guide (With Examples and Tips)',
#   0.22136096605744124),
#  ('Interview Question: "What Is Your Greatest Accomplishment?"',
#   0.21902197563098344),
#  ('The People You Might Meet in an Interview', 0.21785248041775457),
#  ("Jobs That Don't Require a Degree", 0.21129786771105308),
#  ('How To List Education on a Resume', 0.21121627502175802),
#  ('Ways To Conduct Employee Performance Appraisals', 0.2058039599651871),
#  ('Chronological Resume Tips and Examples', 0.20523281114012185),
#  ('How To Show a Promotion on Your Resume', 0.20254025239338555),
#  ('How To Change Careers', 0.19990208877284593),
#  ('Job Search Guide for Former Military Members', 0.19685596170583114),
#  ('Time Management Skills: Definition and Examples', 0.19609442993907744),
#  ('Building Rapport: Tips and Examples', 0.19473455178416013),
#  ('Become a Networking Expert in 7 Steps', 0.19337467362924282),
#  ('Guide To Thank You Notes', 0.19321148825065274),
#  ('15 Popular Chemistry Degree Jobs', 0.19223237597911227),
#  ('Best Careers for ISTJ Personalities', 0.1890230635335074),
#  ('Human Resources: Definition and How It Works', 0.1890230635335074),
#  ('27 Proofreading Tips That Will Improve Your Resume', 0.18858790252393384),
#  ('Conflict Resolution Skills: Definition and Examples', 0.18812554395126194),
#  ('15 Customer Service Jobs That Pay Well', 0.18758159268929503),
#  ('How To Give an Elevator Pitch (With Examples)', 0.18739120974760662),
#  ('Transferable Skills: Definitions and Examples', 0.1824140557006092),
#  ('College Degrees With the Highest Starting Salaries', 0.18053742384682334),
#  ('How to Ask for a Raise (With Script Examples)', 0.18042863359442993),
#  ('Best Careers for ESFJ Personalities', 0.17950391644908614),
#  ('Guide to Submitting a Writing Sample', 0.1784160139251523),
#  ('Best Font for a Resume: How To Choose Type and Size', 0.16876087902523934),
#  ('Guide: 16 Personality Types', 0.1683257180156658),
#  ('10 Tips for Giving a Great Presentation', 0.1632941688424717),
#  ('The Essential Job Search Guide', 0.16242384682332464),
#  ('Best Careers for INTP Personalities', 0.15712032201914708),
#  ('How To Succeed at a Group Interview', 0.14896105308964316),
#  ('A Complete Resume Summary Guide (40+ Examples)', 0.14762837249782418),
#  ('The Path To C-Level Jobs: Working Towards Executive Management',
#   0.14686684073107048),
#  ('14 Sales Jobs That Pay Well', 0.14683964316797213),
#  ('18 Top Economics Degree Jobs', 0.1390339425587467),
#  ('Good and Bad Excuses for Missing Work', 0.13726610095735423),
#  ('What to Wear: The Best Job Interview Attire', 0.13664055700609226),
#  ('Guide To Severance Pay', 0.13541666666666666),
#  ('Informational Interview Questions', 0.1325065274151436),
#  ('39 Strengths and Weaknesses to Discuss in a Job Interview',
#   0.12815491731940817),
#  ('Technical Resume Writing: Tips and Examples', 0.12733899042645777),
#  ("How to Give Two Weeks' Notice (With Examples)", 0.12532637075718014),
#  ('10 Highest Paid Nursing Jobs', 0.1248912097476066),
#  ('16 Accounting Jobs That Pay Well', 0.12296018276762401),
#  ('Interpersonal Skills: Definitions and Examples', 0.12187228024369015),
#  ('What To Do After Getting Fired', 0.12154590948651),
#  ("What to Do If You Aren't Hearing Back From Employers", 0.11896214099216709),
#  ('16 Top Political Science Degree Jobs', 0.1189077458659704),
#  ('Email Examples: How To Respond To a Recruiter', 0.11844538729329851),
#  ('How To Write a Sick Day Email Message (With Examples)',
#   0.11803742384682331),
#  ('How to Succeed in Your New Job: The First Week, Month and 90 Days',
#   0.1174390774586597),
#  ('The Importance of Positive Feedback and How To Deliver It To Others',
#   0.11384899912967798),
#  ('How to Accept a Job Offer', 0.11257071366405569),
#  ('Writing a Resume With No Experience', 0.11229873803307222),
#  ('Using Performance Management in the Workplace', 0.11153720626631852),
#  ('6 Universal Rules for Resume Writing (With Video)', 0.10250761531766753),
#  ('Follow-Up Email Examples For After the Interview', 0.10190926892950392),
#  ('10 Resume Writing Tips To Help You Land a Job', 0.09850957354221061),
#  ('Tips to Demonstrate Work Ethic', 0.09478350739773715),
#  ('Guide To Business Attire (With Examples)', 0.09190056570931245),
#  ('10 Best Skills To Include on a Resume (With Examples)',
#   0.08874564838990426),
#  ('How to Explain Your Reasons for Leaving a Job (With Examples)',
#   0.08344212358572671),
#  ('SWOT Analysis Guide (With Examples)', 0.08292536988685814),
#  ('15 Best Jobs for Introverts', 0.07816579634464751),
#  ('12 Human Resources Jobs That Pay Well', 0.07133920800696257),
#  ('Documentation in the Workplace', 0.06725957354221061),
#  ('Job Search Guide: Product Management and Software Engineering',
#   0.06557332463011314),
#  ('Guide: How to Succeed at a Hiring Event or Open Interview',
#   0.06532854656222802),
#  ('What Is Inductive Reasoning? (Plus Examples of How to Use It)',
#   0.06331592689295039),
#  ('How to Create a Resume Template in Word', 0.06089534377719756),
#  ('12 Retail Jobs That Pay Well', 0.05806679721496954),
#  ('Self Discipline: Definition and Examples', 0.05366079199303742),
#  ('15 Marketing Jobs That Pay Well', 0.04808529155787641),
#  ('Ultimate Guide To Work-Life Balance', 0.047813315926892946),
#  ('High School Resume Tips and Example', 0.04231940818102698),
#  ('11 Popular Travel Jobs', 0.021785248041775455),
#  ('11 Online Jobs for Work Flexibility', 0.015094647519582246),
#  ('Deductive Reasoning: Definition and Examples', 0.012402088772845953),
#  ('15 Entry-Level Jobs That Pay Well', -0.006010661444734551),
#  ('Work-From-Home Jobs That Pay Well', -0.020370974760661444),
#  ('12 Health Care Jobs That Pay Well', -0.03296344647519582)]

# %% [markdown]
# **!!Good results!!**
